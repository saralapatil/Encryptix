# %%
import pandas
import numpy

# %%
df_train =pandas.read_csv('fraudTrain.csv')

# %%
df_train
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
df_test = pandas.read_csv('fraudTest.csv')

# %%
df_test
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
import pandas 

# Load the dataset
df_test = pandas.read_csv('fraudTest.csv')

# Print the column names
print(df_test.columns)
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
# Get the column names as a list
column_names = df_test.columns.tolist()

# Print the list of column names
print(column_names)
# Out:
# ['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud']

# %%
print(df_train.columns)
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
print(df_test.columns)
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
# Assuming your DataFrame is named df
# List of columns to drop
columns_to_drop = ['Unnamed: 0', 'first', 'last', 'street', 'dob', 'job']

# Drop the specified columns
df_train = df_train.drop(columns=columns_to_drop)

# If you want to drop the columns in place without creating a new DataFrame
# df.drop(columns=columns_to_drop, inplace=True)

# Display the updated DataFrame

df_test = df_test.drop(columns=columns_to_drop)

# %%
print(df_train)
# Out:
#         trans_date_trans_time               cc_num  \
# 0         2019-01-01 00:00:18     2703186189652095
# 1         2019-01-01 00:00:44         630423337322
# 2         2019-01-01 00:00:51       38859492057661
# 3         2019-01-01 00:01:16     3534093764340240
# 4         2019-01-01 00:03:06      375534208663984
# ...                       ...                  ...
# 1296670   2020-06-21 12:12:08       30263540414123
# 1296671   2020-06-21 12:12:19     6011149206456997
# 1296672   2020-06-21 12:12:32     3514865930894695
# 1296673   2020-06-21 12:13:36     2720012583106919
# 1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt gender  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97      F
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F
# 2                       fraud_Lind-Buckridge  entertainment  220.11      M
# ...

# %%
print(df_test)
# Out:
#        trans_date_trans_time            cc_num  \
# 0        2020-06-21 12:14:25  2291163933867244
# 1        2020-06-21 12:14:33  3573030041201292
# 2        2020-06-21 12:14:53  3598215285024754
# 3        2020-06-21 12:15:15  3591919803438423
# 4        2020-06-21 12:15:17  3526826139003047
# ...                      ...               ...
# 555714   2020-12-31 23:59:07    30560609640617
# 555715   2020-12-31 23:59:09  3556613125071656
# 555716   2020-12-31 23:59:15  6011724471098086
# 555717   2020-12-31 23:59:24     4079773899158
# 555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt gender  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86      M
# 1                       fraud_Sporer-Keebler   personal_care   29.84      F
# 2       fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28      F
# 3                          fraud_Haley Group        misc_pos   60.05      M
# ...

# %%
df_test['trans_date_trans_time'] = pandas.to_datetime(df_test['trans_date_trans_time'])
df_test['hour'] = df_test['trans_date_trans_time'].dt.hour
df_test['hour']
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 555714    23
# 555715    23
# 555716    23
# 555717    23
# 555718    23
# Name: hour, Length: 555719, dtype: int32

# %%
df_train['trans_date_trans_time'] = pandas.to_datetime(df_train['trans_date_trans_time'])
df_train['hour'] = df_train['trans_date_trans_time'].dt.hour
df_train['hour']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1296670    12
# 1296671    12
# 1296672    12
# 1296673    12
# 1296674    12
# Name: hour, Length: 1296675, dtype: int32

# %%
# Drop the 'trans_date_trans_time' column from both datasets
df_train.drop(columns=['trans_date_trans_time'], inplace=True)
df_test.drop(columns=['trans_date_trans_time'], inplace=True)

# Verify the column has been dropped by displaying the columns
print("Columns in the training dataset after dropping 'trans_date_trans_time':")
print(df_train.columns)

print("Columns in the testing dataset after dropping 'trans_date_trans_time':")
print(df_test.columns)
# Out:
# Columns in the training dataset after dropping 'trans_date_trans_time':
# Index(['cc_num', 'merchant', 'category', 'amt', 'gender', 'city', 'state',
#        'zip', 'lat', 'long', 'city_pop', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'hour'],
#       dtype='object')
# Columns in the testing dataset after dropping 'trans_date_trans_time':
# Index(['cc_num', 'merchant', 'category', 'amt', 'gender', 'city', 'state',
#        'zip', 'lat', 'long', 'city_pop', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud', 'hour'],
#       dtype='object')

# %%
df_train.head()
# Out:
#              cc_num                            merchant       category  \
# 0  2703186189652095          fraud_Rippin, Kub and Mann       misc_net
# 1      630423337322     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2    38859492057661                fraud_Lind-Buckridge  entertainment
# 3  3534093764340240  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   375534208663984                 fraud_Keeling-Crist       misc_pos
#
#       amt gender            city state    zip      lat      long  city_pop  \
# 0    4.97      F  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1  107.23      F          Orient    WA  99160  48.8878 -118.2105       149
# 2  220.11      M      Malad City    ID  83252  42.1808 -112.2620      4154
# 3   45.00      M         Boulder    MT  59632  46.2306 -112.1138      1939
# 4   41.96      M        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# ...

# %%
df_test.head()
# Out:
#              cc_num                              merchant        category  \
# 0  2291163933867244                 fraud_Kirlin and Sons   personal_care
# 1  3573030041201292                  fraud_Sporer-Keebler   personal_care
# 2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3  3591919803438423                     fraud_Haley Group        misc_pos
# 4  3526826139003047                 fraud_Johnston-Casper          travel
#
#      amt gender        city state    zip      lat      long  city_pop  \
# 0   2.86      M    Columbia    SC  29209  33.9659  -80.9355    333497
# 1  29.84      F     Altonah    UT  84002  40.3207 -110.4360       302
# 2  41.28      F    Bellmore    NY  11710  40.6729  -73.5365     34496
# 3  60.05      M  Titusville    FL  32780  28.5697  -80.8191     54767
# 4   3.19      M    Falmouth    MI  49632  44.2529  -85.0170      1126
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# ...

# %%
# Drop the 'trans_date_trans_time' column from both datasets
df_train.drop(columns=['trans_num','unix_time'], inplace=True)
df_test.drop(columns=['trans_num','unix_time'], inplace=True)

# Verify the column has been dropped by displaying the columns
print("Columns in the training dataset after dropping 'trans_num','unix_time':")
print(df_train.columns)

print("Columns in the testing dataset after dropping 'trans_num','unix_time':")
print(df_test.columns)
# Out:
# Columns in the training dataset after dropping 'trans_num','unix_time':
# Index(['cc_num', 'merchant', 'category', 'amt', 'gender', 'city', 'state',
#        'zip', 'lat', 'long', 'city_pop', 'merch_lat', 'merch_long', 'is_fraud',
#        'hour'],
#       dtype='object')
# Columns in the testing dataset after dropping 'trans_num','unix_time':
# Index(['cc_num', 'merchant', 'category', 'amt', 'gender', 'city', 'state',
#        'zip', 'lat', 'long', 'city_pop', 'merch_lat', 'merch_long', 'is_fraud',
#        'hour'],
#       dtype='object')

# %%
df_train.head()
# Out:
#              cc_num                            merchant       category  \
# 0  2703186189652095          fraud_Rippin, Kub and Mann       misc_net
# 1      630423337322     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2    38859492057661                fraud_Lind-Buckridge  entertainment
# 3  3534093764340240  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   375534208663984                 fraud_Keeling-Crist       misc_pos
#
#       amt gender            city state    zip      lat      long  city_pop  \
# 0    4.97      F  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1  107.23      F          Orient    WA  99160  48.8878 -118.2105       149
# 2  220.11      M      Malad City    ID  83252  42.1808 -112.2620      4154
# 3   45.00      M         Boulder    MT  59632  46.2306 -112.1138      1939
# 4   41.96      M        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#    merch_lat  merch_long  is_fraud  hour
# 0  36.011293  -82.048315         0     0
# ...

# %%
df_test.head()
# Out:
#              cc_num                              merchant        category  \
# 0  2291163933867244                 fraud_Kirlin and Sons   personal_care
# 1  3573030041201292                  fraud_Sporer-Keebler   personal_care
# 2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3  3591919803438423                     fraud_Haley Group        misc_pos
# 4  3526826139003047                 fraud_Johnston-Casper          travel
#
#      amt gender        city state    zip      lat      long  city_pop  \
# 0   2.86      M    Columbia    SC  29209  33.9659  -80.9355    333497
# 1  29.84      F     Altonah    UT  84002  40.3207 -110.4360       302
# 2  41.28      F    Bellmore    NY  11710  40.6729  -73.5365     34496
# 3  60.05      M  Titusville    FL  32780  28.5697  -80.8191     54767
# 4   3.19      M    Falmouth    MI  49632  44.2529  -85.0170      1126
#
#    merch_lat  merch_long  is_fraud  hour
# 0  33.986391  -81.200714         0    12
# ...

# %%
import pandas 
from sklearn.preprocessing import LabelEncoder
import numpy as np


# List of categorical columns to be label encoded
categorical_columns = ['merchant', 'category', 'gender', 'city', 'state']

# Initialize the label encoder
label_encoder = LabelEncoder()

# Function to apply label encoding
def apply_label_encoding(train_df, test_df, columns):
    for column in columns:
        # Fit the label encoder on the training data
        label_encoder.fit(train_df[column])
        
        # Transform the training data
        train_df[column] = label_encoder.transform(train_df[column])
        
        # Handle unknown categories in the test data
        test_df[column] = test_df[column].map(lambda s: '<unknown>' if s not in label_encoder.classes_ else s)
        label_encoder.classes_ = np.append(label_encoder.classes_, '<unknown>')
        test_df[column] = label_encoder.transform(test_df[column])
        
    return train_df, test_df

# Apply label encoding to the specified columns
df_train_encoded, df_test_encoded = apply_label_encoding(df_train, df_test, categorical_columns)

# Verify the transformation
print("First few rows of the training dataset after label encoding:")
print(df_train_encoded.head())

print("First few rows of the testing dataset after label encoding:")
print(df_test_encoded.head())
# Out:
# First few rows of the training dataset after label encoding:
#              cc_num  merchant  category     amt  gender  city  state    zip  \
# 0  2703186189652095       514         8    4.97       0   526     27  28654
# 1      630423337322       241         4  107.23       0   612     47  99160
# 2    38859492057661       390         0  220.11       1   468     13  83252
# 3  3534093764340240       360         2   45.00       1    84     26  59632
# 4   375534208663984       297         9   41.96       1   216     45  24433
#
#        lat      long  city_pop  merch_lat  merch_long  is_fraud  hour
# 0  36.0788  -81.1781      3495  36.011293  -82.048315         0     0
# 1  48.8878 -118.2105       149  49.159047 -118.186462         0     0
# 2  42.1808 -112.2620      4154  43.150704 -112.154481         0     0
# 3  46.2306 -112.1138      1939  47.034331 -112.561071         0     0
# 4  38.4207  -79.4629        99  38.674999  -78.632459         0     0
# ...

# %%
df_train.head()
# Out:
#              cc_num  merchant  category     amt  gender  city  state    zip  \
# 0  2703186189652095       514         8    4.97       0   526     27  28654
# 1      630423337322       241         4  107.23       0   612     47  99160
# 2    38859492057661       390         0  220.11       1   468     13  83252
# 3  3534093764340240       360         2   45.00       1    84     26  59632
# 4   375534208663984       297         9   41.96       1   216     45  24433
#
#        lat      long  city_pop  merch_lat  merch_long  is_fraud  hour
# 0  36.0788  -81.1781      3495  36.011293  -82.048315         0     0
# 1  48.8878 -118.2105       149  49.159047 -118.186462         0     0
# 2  42.1808 -112.2620      4154  43.150704 -112.154481         0     0
# 3  46.2306 -112.1138      1939  47.034331 -112.561071         0     0
# 4  38.4207  -79.4629        99  38.674999  -78.632459         0     0

# %%
df_train.shape
# Out:
# (1296675, 15)

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
import pandas 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, precision_recall_curve, auc
import matplotlib.pyplot as plt


# Split into features and target
X_train = df_train.drop(columns=['is_fraud'])
y_train = df_train['is_fraud']
X_test = df_test.drop(columns=['is_fraud'])
y_test = df_test['is_fraud']

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the testing data
X_test_scaled = scaler.transform(X_test)

# %%
# Define the parameter grid
param_grid = {
    'criterion': ['gini'],
    'splitter': [ 'random'],
    'max_depth': [None, 20],
    'min_samples_split': [2],
    'min_samples_leaf': [ 5],
    'min_weight_fraction_leaf': [ 0.1],
    'max_features': [None, 'auto'],
    'random_state': [42],
    'max_leaf_nodes': [None, 10],
    'min_impurity_decrease': [ 0.01],
    'class_weight': ['balanced'],
    'ccp_alpha': [ 0.1]
}

# Initialize the DecisionTreeClassifier
dtree = DecisionTreeClassifier()

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=dtree, param_grid=param_grid, scoring='accuracy', cv=2, n_jobs=-1, verbose=2)

# Fit GridSearchCV
grid_search.fit(X_train_scaled, y_train)

# Best parameters
print("Best parameters found: ", grid_search.best_params_)
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 8 fits failed out of a total of 16.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
# Train the model with best parameters
best_dtree = grid_search.best_estimator_

# Fit the model on the training data
best_dtree.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred = best_dtree.predict(X_test_scaled)

# %%
# Calculate accuracy, precision, recall
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# Print metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Confusion Matrix:\n{conf_matrix}")

# Calculate True Positive, True Negative, False Positive, False Negative
TN, FP, FN, TP = conf_matrix.ravel()

# Print TP, TN, FP, FN
print(f"True Positive (TP): {TP}")
print(f"True Negative (TN): {TN}")
print(f"False Positive (FP): {FP}")
print(f"False Negative (FN): {FN}")
# Out:
# Accuracy: 0.0038598644278853163
# Precision: 0.0038598644278853163
# Recall: 1.0
# Confusion Matrix:
# [[     0 553574]
#  [     0   2145]]
# True Positive (TP): 2145
# True Negative (TN): 0
# False Positive (FP): 553574
# False Negative (FN): 0

# %%
# Compute ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, best_dtree.predict_proba(X_test_scaled)[:,1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Compute Precision-Recall curve
precision_curve, recall_curve, _ = precision_recall_curve(y_test, best_dtree.predict_proba(X_test_scaled)[:,1])
pr_auc = auc(recall_curve, precision_curve)

# Plot Precision-Recall curve
plt.figure()
plt.plot(recall_curve, precision_curve, color='blue', lw=2, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()
